# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris=load_iris()
data=pd.DataFrame(data=iris.data,columns=iris.feature_names)
data["target"]=iris.target
data["target"]=data["target"].map({0: "seronosa",1: "halo",2:"yelo"})
print(data.head())
print(data.describe)
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)    target
# 0                5.1               3.5  ...               0.2  seronosa
# 1                4.9               3.0  ...               0.2  seronosa
# 2                4.7               3.2  ...               0.2  seronosa
# 3                4.6               3.1  ...               0.2  seronosa
# 4                5.0               3.6  ...               0.2  seronosa
#
# [5 rows x 5 columns]
# <bound method NDFrame.describe of      sepal length (cm)  sepal width (cm)  ...  petal width (cm)    target
# 0                  5.1               3.5  ...               0.2  seronosa
# 1                  4.9               3.0  ...               0.2  seronosa
# 2                  4.7               3.2  ...               0.2  seronosa
# 3                  4.6               3.1  ...               0.2  seronosa
# 4                  5.0               3.6  ...               0.2  seronosa
# ...

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris=load_iris()
data=pd.DataFrame(data=iris,columns=iris.columns,target="target")
data["target"]=data["target"].map({0:"seronova",1:"visalovo",2:"wallahi"})
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\~samay\Lib\site-packages\sklearn\utils\_bunch.py:54, in Bunch.__getattr__(self, key)
#      53 try:
# ---> 54     return self[key]
#      55 except KeyError:
#
# File c:\Users\User\~samay\Lib\site-packages\sklearn\utils\_bunch.py:39, in Bunch.__getitem__(self, key)
#      35     warnings.warn(
#      36         self._deprecated_key_to_warnings[key],
#      37         FutureWarning,
#      38     )
# ---> 39 return super().__getitem__(key)
#
# KeyError: 'columns'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       2 import pandas as pd
#       4 iris=load_iris()
# ----> 5 data=pd.DataFrame(data=iris,columns=iris.columns,target="target")
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(data)
plt.show()

# %%
from sklearn.datasets import load_iris
import seaborn as sns
import pandas as pd

iris=load_iris()
data=pd.DataFrame(data=iris.data,columns=iris.feature_names)

data["target"]=iris.target
data["target"]=data["target"].map({0:"seronova",1:"berno",3:"flacko"})
sns.boxplot(data)
# Out:
# <Axes: >
